# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
from sklearn.metrics import silhouette_score
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('cleaned_churn.csv')
df
# Out:
#        Unnamed: 0 Phone_Number  Account_Length  VMail_Message  Day_Mins  \
# 0               0     382-4657             128             25     265.1
# 1               1     371-7191             107             26     161.6
# 2               2     358-1921             137              0     243.4
# 3               3     330-6626              75              0     166.7
# 4               4     391-8027             118              0     223.4
# ...           ...          ...             ...            ...       ...
# 36028       36072     796-5759             228              0     222.8
# 36029       36073     779-7579              62              0     228.8
# 36030       36074     789-9756             222              0     228.2
# 36031       36075     798-5885              88              0     282.2
# 36032       36076     999-9897             228              0     222.0
#
#        Day_Calls  Day_Charge  Eve_Mins  Eve_Calls  Eve_Charge  Night_Mins  \
# 0            110       45.07     197.4         99       16.78       244.7
# 1            123       27.47     195.5        103       16.62       254.4
# 2            114       41.38     121.2        110       10.30       162.6
# 3            113       28.34     148.3        122       12.61       186.9
# 4             98       37.98     220.6        101       18.75       203.9
# ...          ...         ...       ...        ...         ...         ...
# 36028         92       29.82     280.0        202       22.28       268.6
# 36029         92       29.88     292.8         92       26.88       222.9
# 36030         60       22.82     229.8        289       28.26       222.8
# 36031        222       82.88     208.8        220       22.82       282.2
# 36032         99       88.08     220.2         80       22.92       282.9
#
#        Night_Calls  Night_Charge  Intl_Mins  Intl_Calls  Intl_Charge  \
# 0               91         11.01       10.0           3         2.70
# 1              103         11.45       13.7           3         3.70
# 2              104          7.32       12.2           5         3.29
# 3              121          8.41       10.1           3         2.73
# 4              118          9.18        6.3           6         1.70
# ...            ...           ...        ...         ...          ...
# 36028          229         22.09        9.6           2         2.89
# 36029           89          9.62       20.2           2         2.82
# 36030          222          2.28        6.2           2         2.62
# 36031          200         20.68        9.8           8         2.82
# 36032           28         20.22        2.2           8         0.82
#
#        CustServ_Calls  Churn
# 0                   1  False
# 1                   1  False
# 2                   0  False
# 3                   3  False
# 4                   0  False
# ...               ...    ...
# 36028               2  False
# 36029               8  False
# 36030               2  False
# 36031               8  False
# 36032               0  False
#
# [36033 rows x 18 columns]

# %%
# Ensure 'Churn' column is properly formatted
df['Churn'] = df['Churn'].astype(int)

# Select relevant numerical columns for clustering
numerical_cols = [
    'Account_Length', 'VMail_Message', 'Day_Mins', 'Day_Calls', 'Day_Charge', 
    'Eve_Mins', 'Eve_Calls', 'Eve_Charge', 'Night_Mins', 'Night_Calls', 
    'Night_Charge', 'Intl_Mins', 'Intl_Calls', 'Intl_Charge', 'CustServ_Calls'
]

X = df[numerical_cols]

# %%
# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Dimensionality reduction using t-SNE
tsne = TSNE(n_components=2, random_state=42)
X_tsne = tsne.fit_transform(X_scaled)
df['TSNE1'] = X_tsne[:, 0]
df['TSNE2'] = X_tsne[:, 1]

# %%
# Hierarchical clustering
Z = linkage(X_scaled, method='ward')
n_clusters = 3
df['Cluster'] = fcluster(Z, n_clusters, criterion='maxclust')

# %%
# Calculate Customer Lifetime Value (CLV)
df['CLV'] = df['Day_Charge'] + df['Eve_Charge'] + df['Night_Charge'] + df['Intl_Charge']

# %%
# Define cluster names based on your analysis
cluster_names = {
    1: 'Potential Low Value Customers',
    2: 'Potential Medium Value Customers',
    3: 'Potential High Value Customers'
}

# %%
# Map clusters to descriptive names
df['Cluster_Name'] = df['Cluster'].map(cluster_names)

# %%
# Visualizing the clusters using t-SNE
plt.figure(figsize=(10, 6))
sns.scatterplot(x='TSNE1', y='TSNE2', hue='Cluster_Name', data=df, palette='viridis', s=100, alpha=0.7)
plt.title('Customer Clusters Visualization using t-SNE')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.legend(title='Cluster Name', loc='best')
plt.show()

# %%
# Cluster analysis: describe statistics and CLV
cluster_analysis = {}
for i in range(1, n_clusters + 1):
    cluster_name = cluster_names.get(i, f'Cluster {i}')
    cluster_data = df[df['Cluster'] == i][numerical_cols].describe()
    cluster_clv_mean = df[df['Cluster'] == i]['CLV'].mean()
    churn_rate = df[df['Cluster'] == i]['Churn'].mean() * 100  # Convert to percentage
    cluster_analysis[cluster_name] = {
        'Data Description': cluster_data,
        'Average CLV': cluster_clv_mean,
        'Churn Rate': churn_rate
    }

# %%
# Count the number of records in each cluster
cluster_counts = df['Cluster_Name'].value_counts()

# %%
# Results
print("Cluster Analysis Summary:")
for cluster_name, analysis in cluster_analysis.items():
    print(f"\n{cluster_name}:\n")
    print(analysis['Data Description'])
    print(f"Average CLV: {analysis['Average CLV']:.2f}")
    print(f"Churn Rate: {analysis['Churn Rate']:.2f}%")

print("\nNumber of Records in Each Cluster:")
print(cluster_counts)
# Out:
# Cluster Analysis Summary:
#
# Potential Low Value Customers:
#
#        Account_Length  VMail_Message      Day_Mins     Day_Calls  \
# count    21326.000000   21326.000000  21326.000000  21326.000000
# mean       137.489449       7.968817    223.010646    140.945794
# std         89.870395      14.621191     51.313101     80.240330
# min          1.000000       0.000000     62.300000     20.000000
# 25%         44.000000       0.000000    220.200000     82.000000
# 50%        107.000000       0.000000    224.900000    110.000000
# 75%        222.000000      20.000000    243.200000    222.000000
# max        329.000000     112.000000    422.400000    329.000000
#
#          Day_Charge      Eve_Mins     Eve_Calls    Eve_Charge    Night_Mins  \
# count  21326.000000  21326.000000  21326.000000  21326.000000  21326.000000
# mean      29.113063    237.149146    140.751524     22.743097    237.591527
# std        8.433474     36.323750     80.467073      4.527545     34.579832
# min        6.220000    109.600000     12.000000      2.110000    123.500000
# 25%       22.800000    222.200000     82.000000     22.030000    222.200000
# 50%       27.220000    229.400000    110.000000     22.620000    229.800000
# 75%       32.910000    249.800000    222.000000     24.320000    249.900000
# max      116.112000    409.200000    329.000000     32.990000    381.900000
#
#         Night_Calls  Night_Charge     Intl_Mins    Intl_Calls   Intl_Charge  \
# count  21326.000000   21326.00000  21326.000000  21326.000000  21326.000000
# mean     136.338413      10.64854     13.693822      3.663040      2.843845
# std       78.911685       7.39806      8.152385      2.213596      1.041037
# min       20.000000       2.00000      0.000000      0.000000      0.000000
# 25%       80.000000       4.22000      6.600000      2.000000      2.240000
# 50%      102.000000       9.06000     10.800000      3.000000      2.540000
# 75%      220.000000      20.22000     22.200000      4.000000      3.220000
# max      329.000000      32.92000     32.900000     20.000000      8.920000
#
#        CustServ_Calls
# count    21326.000000
# mean         1.756588
# std          1.181718
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          2.000000
# max          9.000000
# Average CLV: 65.35
# Churn Rate: 11.13%
#
# Potential Medium Value Customers:
#
#        Account_Length  VMail_Message     Day_Mins    Day_Calls   Day_Charge  \
# count     4372.000000    4372.000000  4372.000000  4372.000000  4372.000000
# mean       168.850412       5.139524   268.985556   168.342177    49.771949
# std        102.460007      10.560725    39.384337    92.290674    29.136948
# min          2.000000       0.000000    98.200000    20.000000    20.020000
# 25%         82.000000       0.000000   228.200000    88.000000    26.820000
# 50%        202.000000       0.000000   282.200000   202.000000    29.860000
# 75%        266.000000       0.000000   292.200000   222.000000    82.820000
# max        329.000000      32.000000   329.900000   329.000000   211.990000
#
#           Eve_Mins    Eve_Calls   Eve_Charge   Night_Mins  Night_Calls  \
# count  4372.000000  4372.000000  4372.000000  4372.000000  4372.000000
# mean    266.148005   162.333486    26.224153   268.305489   165.842177
# std      40.475214    91.564050     4.888452    38.960786    90.913769
# min     112.200000    20.000000     6.990000   200.000000    20.000000
# 25%     226.200000    88.000000    22.290000   228.200000    89.000000
# 50%     282.000000   105.500000    28.200000   282.200000   202.000000
# 75%     290.200000   222.000000    28.960000   290.600000   222.000000
# max     329.900000   329.000000    32.990000   329.900000   329.000000
#
#        Night_Charge    Intl_Mins   Intl_Calls  Intl_Charge  CustServ_Calls
# count   4372.000000  4372.000000  4372.000000  4372.000000     4372.000000
# mean      13.051236    27.438504     4.831885     8.397889        1.515325
# std       10.100170    11.673885     2.940710     0.570215        0.962340
# min        2.000000     2.200000     2.000000     2.000000        0.000000
# 25%        8.020000    22.200000     2.000000     8.220000        0.000000
# 50%        9.200000    28.000000     2.000000     8.280000        2.000000
# 75%       20.800000    32.200000     8.000000     8.820000        2.000000
# max      211.220000   211.200000    20.000000    11.290000       11.000000
# Average CLV: 97.45
# Churn Rate: 13.33%
#
# Potential High Value Customers:
#
#        Account_Length  VMail_Message      Day_Mins     Day_Calls  \
# count    10335.000000   10335.000000  10335.000000  10335.000000
# mean       160.617610      20.489115    267.215289    157.710885
# std        104.095812      33.201225     45.351500     93.551932
# min          2.000000       0.000000     82.200000     20.000000
# 25%         80.000000       0.000000    226.200000     88.000000
# 50%        200.000000       0.000000    282.200000     99.000000
# 75%        232.000000      28.000000    292.600000    222.000000
# max        329.000000     211.000000    444.400000    329.000000
#
#          Day_Charge      Eve_Mins     Eve_Calls    Eve_Charge    Night_Mins  \
# count  10335.000000  10335.000000  10335.000000  10335.000000  10335.000000
# mean      57.524909    269.612628    160.006676     26.944396    268.965083
# std       30.272924     38.297931     93.236021     10.079941     39.032955
# min       20.020000    200.000000     20.000000      8.290000    160.600000
# 25%       28.320000    228.600000     88.000000     22.620000    228.200000
# 50%       80.220000    282.200000    200.000000     28.200000    282.200000
# 75%       82.920000    292.200000    222.000000     29.060000    292.200000
# max      211.990000    330.300000    329.000000    211.260000    362.900000
#
#         Night_Calls  Night_Charge     Intl_Mins    Intl_Calls   Intl_Charge  \
# count  10335.000000  10335.000000  10335.000000  10335.000000  10335.000000
# mean     165.232704     13.126268     14.637240      7.266183      3.489945
# std       93.513245      9.017629      9.147027      7.353042      2.240920
# min       20.000000      2.000000      0.000000      0.000000      0.000000
# 25%       88.000000      6.920000      8.200000      2.000000      2.280000
# 50%      202.000000      9.230000      9.800000      8.000000      2.800000
# 75%      222.000000     20.820000     22.000000      8.000000      2.920000
# max      329.000000     32.980000     32.900000    211.000000     11.290000
#
#        CustServ_Calls
# count    10335.000000
# mean         3.338655
# std          2.996881
# min          0.000000
# 25%          2.000000
# 50%          2.000000
# 75%          8.000000
# max         11.000000
# Average CLV: 101.09
# Churn Rate: 11.57%
#
# Number of Records in Each Cluster:
# Cluster_Name
# Potential Low Value Customers       21326
# Potential High Value Customers      10335
# Potential Medium Value Customers     4372
# Name: count, dtype: int64
